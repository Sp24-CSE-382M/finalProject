# %% [markdown]
# ## UPDATES:
# * Single multiplicity label per sink particle (vs. 750 for each simulation snapshot).
# * 14 gas properties per sink particle per snapshot (`[M_tot, L_mag, R_eff, aspect_ratio, T, B, Ne, sig3D, E_grav, E_kin, E_mag, E_int, virial_1, virial_2]`).
# * Sample gas properties at evenly-spaced intervals between start of simulation and time of sink particle formation.

# %% [markdown]
# ### Simulation: `M2e3_R3_S0_T1_B0.01_Res126_n2_sol0.5_42`
# * label: `sim_1`
# * Fiducial STARFORGE simulation (low mass-resolution version).
# * Initial molecular cloud mass: $2000$ solar masses (mass resolution: $\Delta m = 2 \times 10^{-3} \, M_{\odot}$; $2\times10^5$ finite-mass gas particles evolved simulation).
# * Initial cloud radius: 3 parsecs.
# * Output: 751 HDF5 snapshot files (time between snapshots = 1.31186e-05 code_time = 0.0128 Myr).

# %% [markdown]
# ### Files:
# **sink_system_labels.hdf5:** Labels the stellar multiplicity of each sink particle ("star") in each of the 751 simulation snapshots
# * `dataset /sink_IDs`: unique integer IDs for each sink (star) particle formed in simulation; 212  sink particles total.
# * `dataset /labels`  : sink particle multiplicity for each snapshot file in the simulation (`0 = not yet formed`, `1 = single`, `2 = binary`, `3 = triple`, `4 = quadruple system`)
#
# **all_accreted_gas_properties.hdf5:** Contains various gas properties (mass, velocity dispersion, etc.) describing the gas that will eventually accrete onto the sink particle for each sink particle formed in the simulation.
# * `dataset /sink_X` (X = unique sink ID): properties of gas associated with sink particle X.

# %%
import numpy as np
import sys
import os
import h5py
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#datadir = '/home/nina/jupyter-workspace/classes/cse382m/final_project/data/'
#figdir  = '/home/nina/jupyter-workspace/classes/cse382m/final_project/figures_data/'

datadir = '/home/naf999/jupyter-workspace/cse382m/final_project/data/'
figdir  = '/home/naf999/jupyter-workspace/cse382m/final_project/figures_data/'

fname_labels = os.path.join(datadir, 'multiplicity_labels.hdf5')
fname_data   = os.path.join(datadir, 'all_accreted_gas_properties.hdf5')

#fname_1      = os.path.join(datadir, 'all_accreted_gas_properties_749_v1_OLD.hdf5')
#fname_2      = os.path.join(datadir, 'all_accreted_gas_properties_750_v1.hdf5')
#fname_3      = os.path.join(datadir, 'all_accreted_gas_properties_750_v3.hdf5')

# %%
# Unit conversions (code_units to cgs).
m_unit = 1.989e33                                 # [g]
l_unit = 3.086e18                                 # [cm]
v_unit = 100.0                                    # [cm/s]
t_unit = l_unit / v_unit                          # [s]
B_unit = 1e4                                      # [Gauss]
t_unit_myr = t_unit / (3600. * 24. * 365. * 1e6)  # [Myr]
E_unit = m_unit * v_unit**2                       # [erg = g cm^2 s^-2]
L_unit = m_unit * v_unit * l_unit                 # [m cm^2 s^-1]

# %%
# Get all sink IDs and multiplicity labels.
with h5py.File(fname_labels, 'r') as f:
    sink_IDs      = f['sink_IDs'][()]     # shape: (num_sink_particles)
    labels        = f['labels'][()]       # shape: (num_sink_particles)
    idx_formation = f['i_formation'][()]  # idx of snapshot in which sink particle forms.

# %%
# Get accreted gas properties data for each sink particle.
num_sinks      = len(sink_IDs)
sink_data_dict = dict.fromkeys(sink_IDs.astype(np.int64))

with h5py.File(fname_data, 'r') as f:
    for sink_ID in sink_IDs:
        sink_label = 'sink_{0:d}'.format(sink_ID)
        sink_data_dict[sink_ID] = f[sink_label][()]

# %%
# Get indices to return n_points evenly-sampled indices between 1 and idx_first.
def get_idx_vals(idx_first, n_points):
    di        = int(idx_first / (n_points - 1))
    idx_vals  = np.ones((n_points), dtype=int) * idx_first
    for i in range(n_points):
        idx_vals[i] -= i*di
    idx_vals[-1] = max(1, idx_vals[-1])
    #print(idx_vals)
    return idx_vals

# %%
def make_fig(sink_ID, idx_first, n_points, sink_data_dict=sink_data_dict, savefig=False, xmax=3.5):

    data    = sink_data_dict[sink_ID]
    t       = data[:, 25]                         # Current time.
    M_tot   = data[:, 0]                          # Total mass (of gas not yet accreted onto star)
    X_cm    = data[:, 1:4]                        # Center-of-mass position.
    V_cm    = data[:, 4:7]                        # Center-of-mass velocity.
    L_vec   = data[:, 7:10]                       # Total angular momentum vector.
    L_mag   = np.sqrt(np.sum(L_vec**2, axis=1))   # Angular momentum magnitude.
    R_eff   = data[:, 10]                         # Effective radius.
    R_p     = data[:, 11:14]                      # Aspect ratio shape parameters.
    T       = data[:, 14]                         # Average temperature.
    B       = data[:, 15]                         # Average magnetic field magnitude.
    Ne      = data[:, 16]                         # Average electron abundance.
    sig3D   = data[:, 17]                         # 3D velocity dispersion.
    E_grav  = data[:, 18]                         # Gravitational potential energy.
    E_kin   = data[:, 19]                         # Kinetic energy.
    E_mag   = data[:, 20]                         # Magnetic energy.
    E_int   = data[:, 21]                         # Internal/thermal energy.

    aspect_ratio = np.max(R_p, axis=1)/np.min(R_p, axis=1)

    r_cm     = np.sqrt(np.sum(X_cm**2, axis=1))
    v_cm_mag = np.sqrt(np.sum(V_cm**2, axis=1))
    
    fs=12

    fig, axs = plt.subplots(3, 4, figsize=(14, 8), sharex=True)

    axs[0][0].plot(t * t_unit_myr, M_tot, lw=2, c='tab:blue')
    axs[0][0].set_ylabel(r'$M_{\rm tot}$ [$M_{\odot}$]', fontsize=fs)
    axs[1][0].plot(t * t_unit_myr, R_eff, lw=2)
    axs[1][0].set_ylabel(r'$R_{\rm eff}$ [pc]', fontsize=fs)
    axs[2][0].plot(t * t_unit_myr, aspect_ratio, lw=2)
    axs[2][0].set_ylabel(r'aspect ratio', fontsize=fs)
    axs[2][0].set_ylim(ymin=1, ymax=5)
    axs[2][0].set_xlabel(r'$t$ [Myr]', fontsize=fs)
    
    axs[0][1].plot(t * t_unit_myr, sig3D, lw=2)
    axs[0][1].set_ylabel(r'$\sigma_{3D}$ [m/s]', fontsize=fs)
    axs[1][1].plot(t * t_unit_myr, v_cm_mag, lw=2)
    axs[1][1].set_ylabel(r'$|v_{\rm cm}|$ [m/s]', fontsize=fs)
    axs[2][1].plot(t * t_unit_myr, L_mag*L_unit, lw=2)
    axs[2][1].set_ylabel(r'$|L|$ [g cm$^2$ s$^{-1}$]', fontsize=fs)
    axs[2][1].set_xlabel(r'$t$ [Myr]', fontsize=fs)

    axs[0][2].plot(t * t_unit_myr, np.abs(E_grav)*E_unit, lw=2, c='tab:blue', label=r'$|E_{\rm grav}|$')
    axs[0][2].plot(t * t_unit_myr, E_kin*E_unit, lw=2, c='tab:red', label=r'$E_{\rm kin}$')
    axs[0][2].plot(t * t_unit_myr, E_mag*E_unit, lw=2, c='tab:green', label=r'$E_{\rm mag}$')
    axs[0][2].plot(t * t_unit_myr, E_int*E_unit, lw=2, c='tab:orange', label=r'$E_{\rm int}$')
    axs[0][2].set_yscale('log')
    axs[0][2].legend(loc='lower left', fontsize=9)
    axs[0][2].set_ylabel(r'energy [erg]', fontsize=fs)
    axs[1][2].plot(t * t_unit_myr, (2.0*E_kin)/np.abs(E_grav), lw=2, c='tab:blue')
    axs[1][2].set_ylabel(r'$2E_{\rm kin}/|E_{\rm grav}|$', fontsize=fs)
    axs[1][2].set_ylim(ymin=1.0, ymax=1e4)
    axs[1][2].set_yscale('log')
    axs[2][2].plot(t * t_unit_myr, E_mag/E_kin, lw=2, c='tab:blue')
    axs[2][2].set_ylabel(r'$E_{\rm mag}/E_{\rm kin}$', fontsize=fs)
    axs[2][2].set_ylim(ymin=0.0, ymax=5.0)
    axs[2][2].set_xlabel(r'$t$ [Myr]', fontsize=fs)
    
    axs[0][3].plot(t * t_unit_myr, T, lw=2)
    axs[0][3].set_ylabel(r'$\langle T \rangle$ [K]', fontsize=fs)
    axs[0][3].set_ylim(ymin=0, ymax=100)
    axs[1][3].plot(t * t_unit_myr, B, lw=2)
    axs[1][3].set_ylabel(r'$\langle |B| \rangle$ [Gauss]', fontsize=fs)
    axs[1][3].set_ylim(ymin=1e-6, ymax=1e-2)
    axs[1][3].set_yscale('log')
    axs[2][3].plot(t * t_unit_myr, Ne, lw=2)
    axs[2][3].set_ylabel(r'$\langle$e$^-$ per H$\rangle$', fontsize=fs)
    axs[2][3].set_ylim(ymin=1e-10, ymax=1e-5)
    axs[2][3].set_yscale('log')
    axs[2][3].set_xlabel(r'$t$ [Myr]', fontsize=fs)

    for ax in axs:
        for j in range(4):
            
            i_vals = get_idx_vals(idx_first, n_points)
            
            for i in i_vals:
                ax[j].axvline(x=t[i]*t_unit_myr, ymin=0, ymax=1, c='b', ls='--')
            
            ax[j].axvline(x=t[idx_first]*t_unit_myr, ymin=0, ymax=1, c='r', ls='--')
            ax[j].set_xlim(xmin=0.0, xmax=xmax)
            ax[j].grid(True)
        
    fig.tight_layout()
    if savefig:
        plt.savefig(os.path.join(figdir, 'data_sink_{0:d}.png'.format(sink_ID)))
        plt.close()
    else:
        plt.show()

# %%
def get_data_slice(sink_ID, idx_first, n, n_points, sink_data_dict=sink_data_dict, with_units=False):

    i_vals = get_idx_vals(idx_first, n_points)
    i      = i_vals[n]
    
    data    = sink_data_dict[sink_ID]
    t       = data[i, 25]                 # Current time.
    M_tot   = data[i, 0]                  # Total mass (of gas not yet accreted onto star)
    L_vec   = data[i, 7:10]               # Total angular momentum vector.
    L_mag   = np.sqrt(np.sum(L_vec**2))   # Angular momentum magnitude.
    R_eff   = data[i, 10]                 # Effective radius.
    R_p     = data[i, 11:14]              # Aspect ratio shape parameters.
    T       = data[i, 14]                 # Average temperature.
    B       = data[i, 15]                 # Average magnetic field magnitude.
    Ne      = data[i, 16]                 # Average electron abundance.
    sig3D   = data[i, 17]                 # 3D velocity dispersion.
    E_grav  = data[i, 18]                 # Gravitational potential energy.
    E_kin   = data[i, 19]                 # Kinetic energy.
    E_mag   = data[i, 20]                 # Magnetic energy.
    E_int   = data[i, 21]                 # Internal/thermal energy.
    
    virial_1 = 2.0*E_kin/np.abs(E_grav)
    virial_2 = E_mag / E_kin
    
    if with_units:
        t*=t_unit_myr
        M_tot*=m_unit
        L_mag*=L_unit
        R_eff*=l_unit
        B*=B_unit
        sig3D*=v_unit
        E_grav*=E_unit
        E_kin*=E_unit
        E_mag*=E_unit
        E_int*=E_unit
    aspect_ratio = np.max(R_p)/np.min(R_p)
    
    # Add virial parameters, 2E_kin/|E_grav|, and E_mag/E_kin 
    # Remove time from data.
    
    return np.asarray([M_tot, L_mag, R_eff, aspect_ratio, T, B, Ne, sig3D, E_grav, E_kin, E_mag, E_int,
                       virial_1, virial_2])

def get_multi_data_slices(sink_ID, idx_first, n_points, sink_data_dict=sink_data_dict, with_units=False):
    data = np.zeros((n_points, 14))   
    for n in range(n_points):
        slc = get_data_slice(sink_ID, idx_first, n, n_points, sink_data_dict=sink_data_dict, with_units=with_units)
        data[n, :] = np.reshape(slc, (1, 14))
    return data.flatten('F')

# %%
# Get data at t_formation for all sink particles.
def get_data_slices_all_sinks(sink_IDs, idx_formation, sink_data_dict=sink_data_dict, with_units=False):
    n_sinks  = len(sink_IDs)
    all_data = np.zeros((n_sinks, 14))
    for i, sink_ID in enumerate(sink_IDs):
        idx_first = idx_formation[i]
        data = get_data_slice(sink_ID, idx_first, 0, 5, sink_data_dict=sink_data_dict, with_units=with_units)
        all_data[i, :] = data
    return all_data

# Get data at n_points times between start of simulation and t_formation.
def get_data_multislices_all_sinks(sink_IDs, idx_formation, n_points,
                                   sink_data_dict=sink_data_dict, with_units=False):
    n_sinks  = len(sink_IDs)
    all_data = np.zeros((n_sinks, n_points*14))
    for i, sink_ID in enumerate(sink_IDs):
        idx_first = idx_formation[i]
        data = get_multi_data_slices(sink_ID, idx_first, n_points,
                                     sink_data_dict=sink_data_dict, with_units=with_units)
        all_data[i, :] = data
    return all_data

# %%
all_data_1  = get_data_slices_all_sinks(sink_IDs, idx_formation)
all_data_5  = get_data_multislices_all_sinks(sink_IDs, idx_formation, 5)
all_data_10 = get_data_multislices_all_sinks(sink_IDs, idx_formation, 10)
all_data_20 = get_data_multislices_all_sinks(sink_IDs, idx_formation, 20)
all_data_30 = get_data_multislices_all_sinks(sink_IDs, idx_formation, 30)
all_data_50 = get_data_multislices_all_sinks(sink_IDs, idx_formation, 50)
# Out:
# /tmp/ipykernel_14998/2605952049.py:22: RuntimeWarning: invalid value encountered in scalar divide
#   virial_1 = 2.0*E_kin/np.abs(E_grav)
# /tmp/ipykernel_14998/2605952049.py:23: RuntimeWarning: invalid value encountered in scalar divide
#   virial_2 = E_mag / E_kin
# /tmp/ipykernel_14998/2605952049.py:36: RuntimeWarning: invalid value encountered in scalar divide
#   aspect_ratio = np.max(R_p)/np.min(R_p)
# /tmp/ipykernel_14998/2605952049.py:36: RuntimeWarning: divide by zero encountered in scalar divide
#   aspect_ratio = np.max(R_p)/np.min(R_p)

# %%
np.shape(all_data_50)
# Out:
# (212, 700)

# %%
# Save multiple versions of data for each sink particle - sampled at 1, 5, 10, 20, 30, or 50 points between
# start of simulation and time of formation.

fname = os.path.join(datadir, 'gas_data.hdf5')
f     = h5py.File(fname, 'w')

f.create_dataset('data_1point', data=all_data_1)
f.create_dataset('data_5point', data=all_data_5)
f.create_dataset('data_10point', data=all_data_10)
f.create_dataset('data_20point', data=all_data_20)
f.create_dataset('data_30point', data=all_data_30)
f.create_dataset('data_50point', data=all_data_50)
f.create_dataset('sink_IDs', data=np.asarray(sink_IDs), dtype=int)
f.create_dataset('labels', data=labels)
f.close()

# %%
k = 1
sink_ID    = sink_IDs[k]
idx_first  = idx_formation[k]

n_points = 20

make_fig(sink_ID, idx_first, n_points, savefig=False, xmax=4)
# Out:
# /tmp/ipykernel_14998/3674275047.py:21: RuntimeWarning: invalid value encountered in divide
#   aspect_ratio = np.max(R_p, axis=1)/np.min(R_p, axis=1)
# /tmp/ipykernel_14998/3674275047.py:54: RuntimeWarning: invalid value encountered in divide
#   axs[1][2].plot(t * t_unit_myr, (2.0*E_kin)/np.abs(E_grav), lw=2, c='tab:blue')
# /tmp/ipykernel_14998/3674275047.py:58: RuntimeWarning: invalid value encountered in divide
#   axs[2][2].plot(t * t_unit_myr, E_mag/E_kin, lw=2, c='tab:blue')

# %%
# Historgram of multiplicity labels to be used.
fig, ax          = plt.subplots()
n, bins, patches = ax.hist(labels, bins=[1, 2, 3, 4, 5])
fig.tight_layout()
plt.show()
